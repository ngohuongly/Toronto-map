# %%
import pandas as pd

# %%
postal_Canada = 'http://cocl.us/Geospatial_data'

# %%
df=pd.read_csv(postal_Canada)

# %%
df.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %%
postalcode_Canada = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
df1=pd.read_html(postalcode_Canada, header=0)[0]

df1.head(20)
# Out:
#    Postal Code           Borough  \
# 0          M1A      Not assigned
# 1          M2A      Not assigned
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# 7          M8A      Not assigned
# 8          M9A         Etobicoke
# 9          M1B       Scarborough
# 10         M2B      Not assigned
# 11         M3B        North York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M6B        North York
# 15         M7B      Not assigned
# 16         M8B      Not assigned
# 17         M9B         Etobicoke
# 18         M1C       Scarborough
# 19         M2C      Not assigned
#
#                                          Neighborhood
# 0                                        Not assigned
# 1                                        Not assigned
# 2                                           Parkwoods
# ...

# %%
df1_new = df1.drop(df1[(df1['Borough'] == 'Not assigned') ].index)
print(df1_new)
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %%
import numpy as np

# %%
df1_new['Neighborhood'] = np.where(df1_new['Neighborhood'] == 'Not assigned', df1_new['Borough'], df1_new['Neighborhood'])

# %%
df1_new
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %%
df1_new['Latitude'] = pd.Series(df['Latitude'])

# %%
print (df1_new)
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude
# 2                                            Parkwoods  43.763573
# 3                                     Victoria Village  43.770992
# 4                            Regent Park, Harbourfront  43.773136
# 5                     Lawrence Manor, Lawrence Heights  43.744734
# 6          Queen's Park, Ontario Provincial Government  43.727929
# ..                                                 ...        ...
# 160      The Kingsway, Montgomery Road, Old Mill North        NaN
# ...

# %%
df1_new['Longitude'] = pd.Series(df['Longitude'])

# %%
print (df1_new)
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 2                                            Parkwoods  43.763573 -79.188711
# 3                                     Victoria Village  43.770992 -79.216917
# 4                            Regent Park, Harbourfront  43.773136 -79.239476
# 5                     Lawrence Manor, Lawrence Heights  43.744734 -79.239476
# 6          Queen's Park, Ontario Provincial Government  43.727929 -79.262029
# ..                                                 ...        ...        ...
# ...

# %%
df1_new.head(10)
# Out:
#    Postal Code           Borough                                 Neighborhood  \
# 2          M3A        North York                                    Parkwoods
# 3          M4A        North York                             Victoria Village
# 4          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5          M6A        North York             Lawrence Manor, Lawrence Heights
# 6          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 8          M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 9          M1B       Scarborough                               Malvern, Rouge
# 11         M3B        North York                                    Don Mills
# 12         M4B         East York              Parkview Hill, Woodbine Gardens
# 13         M5B  Downtown Toronto                     Garden District, Ryerson
#
#      Latitude  Longitude
# 2   43.763573 -79.188711
# 3   43.770992 -79.216917
# 4   43.773136 -79.239476
# ...
